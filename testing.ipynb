# %%
addprocs(4; exeflags=`--depwarn=no`)
# Out:
# 4-element Array{Int64,1}:
#  2
#  3
#  4
#  5

# %%
using ComputeFramework
ctx = Context()

push!(LOAD_PATH, "/Users/isaac/GoogleDrive/Work/Julia/JuliaUsage/")
import C
import DataStructures.DefaultDict
using Lazy
# Out:
# WARNING: Method definition .^(ComputeFramework.AbstractNode, ComputeFramework.AbstractNode) in module ComputeFramework at /Users/isaac/.julia/v0.5/ComputeFramework/src/operators.jl:46 overwritten at /Users/isaac/.julia/v0.5/ComputeFramework/src/operators.jl:46.
# WARNING: Method definition .^(Number, ComputeFramework.AbstractNode) in module ComputeFramework at /Users/isaac/.julia/v0.5/ComputeFramework/src/operators.jl:47 overwritten at /Users/isaac/.julia/v0.5/ComputeFramework/src/operators.jl:47.
# WARNING: Method definition .^(ComputeFramework.AbstractNode, Number) in module ComputeFramework at /Users/isaac/.julia/v0.5/ComputeFramework/src/operators.jl:48 overwritten at /Users/isaac/.julia/v0.5/ComputeFramework/src/operators.jl:48.
# ...

# %%
files = C.search_dirs("/Users/isaac/github/julia/base/")

a = distribute(files)
b = map(x->C.process_file(x,s), a)
# b = map(C.process_file, a)
# c = reduce(x->map(_->push!(x[2],_), x[1]), DefaultDict{Symbol, Int, Int}(0), b)
# c = reduce(x->map(_->push!(x[2],_), x[1]), 0, b)
# c = reduce(+, 0, b)

# @show compute(Context(), c)
# out = gather(Context(), b).xs
@time out2 = C.collect_dicts( gather(Context(), b).xs) # Maybe move collection back here
# Out:
# On worker 5
# LoadError: On worker 5:
# type Void has no field head
#  in #1 at ./In[18]:7
#  [inlined code] from ./boot.jl:331
#  in Selector at /Users/isaac/GoogleDrive/Work/Julia/JuliaUsage/C.jl:91
#  in parse_ast at /Users/isaac/GoogleDrive/Work/Julia/JuliaUsage/C.jl:101
#  in parse_ast at /Users/isaac/GoogleDrive/Work/Julia/JuliaUsage/C.jl:99
#  [inlined code] from /Users/isaac/GoogleDrive/Work/Julia/JuliaUsage/C.jl:96
#  in process_file at /Users/isaac/GoogleDrive/Work/Julia/JuliaUsage/C.jl:124
#  in map_to! at ./abstractarray.jl:1235
#  in map at ./abstractarray.jl:1260
#  in #51 at /Users/isaac/.julia/v0.5/ComputeFramework/src/map-reduce.jl:40
#  in #33 at ./multi.jl:1462
#  in run_work_thunk at ./multi.jl:714
#  in run_work_thunk at ./multi.jl:723
#  in #243 at ./task.jl:54
# while loading In[19], in expression starting on line 155
# :
# type Void has no field head
#  in #1 at ./In[18]:7
#  [inlined code] from ./boot.jl:331
# ...

# %% [markdown]
# # Downloading all the repos
#
# ## TODO
#
# * Add updating all repos

# %%
repo_dir = "/Users/isaac/Documents/julia_repos/"
# Out:
# "/Users/isaac/Documents/julia_repos/"

# %%
repo_dir = "/Users/isaac/Documents/julia_repos/"
packages = Pkg.available()
pkg_repo = []
for i in packages
    push!(pkg_repo, [Pkg.Read.url(i), string(repo_dir,i)])
end

# %%
# a = distribute(pkg_repo)
# b = map(x->download_repo(x...), a)

# gather(Context(), b)
# Out:
# fatal: destination path '/Users/isaac/Documents/julia_repos/AbstractDomains' already exists and is not an empty directory.
# fatal: destination path '/Users/isaac/Documents/julia_repos/ColorVectorSpace' already exists and is not an empty directory.
# Cloning into '/Users/isaac/Documents/julia_repos/Escher'...
# fatal: destination path '/Users/isaac/Documents/julia_repos/Libz' already exists and is not an empty directory.
# fatal: destination path '/Users/isaac/Documents/julia_repos/PyLexYacc' already exists and is not an empty directory.
# fatal: destination path '/Users/isaac/Documents/julia_repos/NaNMath' already exists and is not an empty directory.
# fatal: destination path '/Users/isaac/Documents/julia_repos/Hive' already exists and is not an empty directory.
# fatal: destination path '/Users/isaac/Documents/julia_repos/Stan' already exists and is not an empty directory.
# On worker 2:
# ...

# %% [markdown]
# # Reading across all files

# %%
base_dirs = ["/Users/isaac/github/julia/base/","/Users/isaac/github/julia/test/"]
# Out:
# 2-element Array{ASCIIString,1}:
#  "/Users/isaac/github/julia/base/"
#  "/Users/isaac/github/julia/test/"

# %%
@time eco_counts = C.count_exprs(C.search_dirs(repo_dir))
@time base_counts = C.count_exprs(union(map(C.search_dirs, base_dirs)...))
# Out:
# WARNING: deprecated syntax "error (".
# Use "error(" instead.
#
# WARNING: deprecated syntax "error (".
# Use "error(" instead.
#
# WARNING: deprecated syntax "error (".
# Use "error(" instead.
#
# WARNING: deprecated syntax "error (".
# Use "error(" instead.
#
# WARNING: deprecated syntax "error (".
# Use "error(" instead.
#
# WARNING: deprecated syntax "error (".
# Use "error(" instead.
#
# WARNING: deprecated syntax "error (".
# Use "error(" instead.
#
# WARNING: deprecated syntax "waitnexec (".
# Use "waitnexec(" instead.
#
# WARNING: deprecated syntax "[a=>b, ...]".
# Use "Dict(a=>b, ...)" instead.
#
# WARNING: deprecated syntax "{a,b, ...}".
# Use "Any[a,b, ...]" instead.
#
# WARNING: deprecated syntax "{a,b, ...}".
# Use "Any[a,b, ...]" instead.
#
# WARNING: deprecated syntax "(macrocall @r_str [-+]?[0-9]*\.[0-9]+([eE][-+]?[0-9]+)?[Ff]) {".
# Use "(macrocall @r_str [-+]?[0-9]*\.[0-9]+([eE][-+]?[0-9]+)?[Ff]){" instead.
#
# ...

# %%
# using Gadfly # Doesn't work on master

# %%
serialize(open("data/eco_counts.jld", "w"), eco_counts)
serialize(open("data/base_counts.jld", "w"), base_counts)

# %% [markdown]
# # Looking for functions

# %%
temp = """function foo(x)
  x = x + 1
  return x
end
"""

temp2 = """x = foo(5)"""

files = C.search_dirs("/Users/isaac/github/julia/Base/")
# Out:
# 281-element Array{AbstractString,1}:
#  "/Users/isaac/github/julia/Base/Dates.jl"
#  "/Users/isaac/github/julia/Base/Enums.jl"
#  "/Users/isaac/github/julia/Base/LineEdit.jl"
#  "/Users/isaac/github/julia/Base/REPL.jl"
#  "/Users/isaac/github/julia/Base/REPLCompletions.jl"
#  "/Users/isaac/github/julia/Base/Terminals.jl"
#  "/Users/isaac/github/julia/Base/abstractarray.jl"
#  "/Users/isaac/github/julia/Base/abstractarraymath.jl"
#  "/Users/isaac/github/julia/Base/array.jl"
#  "/Users/isaac/github/julia/Base/arraymath.jl"
#  "/Users/isaac/github/julia/Base/ascii.jl"
#  "/Users/isaac/github/julia/Base/atomics.jl"
#  "/Users/isaac/github/julia/Base/base.jl"
#  ⋮
#  "/Users/isaac/github/julia/Base/unicode/UnicodeError.jl"
#  "/Users/isaac/github/julia/Base/unicode/checkstring.jl"
#  "/Users/isaac/github/julia/Base/unicode/types.jl"
#  "/Users/isaac/github/julia/Base/unicode/utf16.jl"
#  "/Users/isaac/github/julia/Base/unicode/utf32.jl"
#  "/Users/isaac/github/julia/Base/unicode/utf8.jl"
# ...

# %%
parse(temp)
# Out:
# :(function foo(x) # none, line 2:
#         x = x + 1 # none, line 3:
#         return x
#     end)

# %%
xdump(parse(temp2))
# Out:
# Expr
#   head: Symbol =
#   args: Array(Any,(2,))
#     1: Symbol x
#     2: Expr
#       head: Symbol call
#       args: Array(Any,(2,))
#         1: Symbol foo
#         2: Int64 5
#       typ: Any::DataType  <: Any
#   typ: Any::DataType  <: Any

# %%
out = C.count_exprs(C.search_dirs(base_dir), C.Selector([x->x.head == :call, x->length(x.args) >=1]))
temp2 = @>> out map(x->x.args[1]) counter x->x.map
# temp3 = @> temp2 values collect counter x->x.map

# %% [markdown]
# # Distribute over repos/ files

# %%
eco_dir = "/Users/isaac/Documents/julia_repos/"
repo_dirs = filter(isdir, map(x->joinpath(eco_dir,x), readdir(eco_dir)))
a = distribute(repo_dirs)
b = map(x->x=>length(C.search_dirs(x))#If this function returned a repo-summary pair, that'd work out great.
    , a)
c = reducebykey(+, 0, b)

@show compute(Context(), c)
# Out:
# compute(Context(),c) = Dict{Any,Any}("/Users/isaac/Documents/julia_repos/ManifoldLearning"=>19,"/Users/isaac/Documents/julia_repos/GARCH"=>3,"/Users/isaac/Documents/julia_repos/Bokeh"=>32,"/Users/isaac/Documents/julia_repos/RouletteWheels"=>2,"/Users/isaac/Documents/julia_repos/MatrixMarket"=>3,"/Users/isaac/Documents/julia_repos/MFCC"=>7,"/Users/isaac/Documents/julia_repos/ThermodynamicsTable"=>17,"/Users/isaac/Documents/julia_repos/HypothesisTests"=>27,"/Users/isaac/Documents/julia_repos/Munkres"=>2,"/Users/isaac/Documents/julia_repos/Instruments"=>8,"/Users/isaac/Documents/julia_repos/DocOpt"=>6,"/Users/isaac/Documents/julia_repos/ClusterDicts"=>2,"/Users/isaac/Documents/julia_repos/Clang"=>20,"/Users/isaac/Documents/julia_repos/Mocking"=>11,"/Users/isaac/Documents/julia_repos/Expect"=>3,"/Users/isaac/Documents/julia_repos/Miniball"=>7,"/Users/isaac/Documents/julia_repos/XSim"=>14,"/Users/isaac/Documents/julia_repos/TikzPictures"=>2,"/Users/isaac/Documents/julia_repos/MIDI"=>17,"/
# ...

# %% [markdown]
# Count modules per file

# %%
out = let eco_dir = "/Users/isaac/Documents/julia_repos/"
    files = C.search_dirs(eco_dir)
    s = C.Selector(Any[[C.field(:head), x->x==:module]])
    a = distribute(files)
    b = map(x->x=>length(C.parse_ast(C.parse_file(x),s)), a)
#     c = reducebykey(+, 0, b)
    res = compute(Context(), c)
    values(res) |> collect |> counter |> x->x.map |> Base.showdict
    res
end;
# Out:
# WARNING: File "/Users/isaac/Documents/julia_repos/FixedEffectModels/benchmark/result.jl" raises error:
# ParseError("extra token \"df\" after end of expression")
# 	From worker 3:	File "/Users/isaac/Documents/julia_repos/FixedEffectModels/benchmark/result.jl" raises error:
# 	From worker 3:	ParseError("extra token \"df\" after end of expression")
# WARNING: File "/Users/isaac/Documents/julia_repos/RLEVectors/benchmark/benchmark_rle_vectors.jl" raises error:
# ParseError("unexpected \"]\" in argument list")
# 	From worker 5:	File "/Users/isaac/Documents/julia_repos/RLEVectors/benchmark/benchmark_rle_vectors.jl" raises error:
# 	From worker 5:	ParseError("unexpected \"]\" in argument list")
# WARNING: File "/Users/isaac/Documents/julia_repos/LowRankModels/test/obj_test.jl" raises error:
# ParseError("missing separator in array expression")
# 	From worker 4:	File "/Users/isaac/Documents/julia_repos/LowRankModels/test/obj_test.jl" raises error:
# ...

# %%
C.count_exprs(
    C.search_dirs("/Users/isaac/Documents/julia_repos/"), 
C.Selector(Any[[C.field(:head), x->x==:module]]))
# Out:
# WARNING: deprecated syntax "{a,b, ...}".
# Use "Any[a,b, ...]" instead.
#
# WARNING: deprecated syntax "{a,b, ...}".
# Use "Any[a,b, ...]" instead.
#
# WARNING: deprecated syntax "(macrocall @r_str [-+]?[0-9]*\.[0-9]+([eE][-+]?[0-9]+)?[Ff]) {".
# Use "(macrocall @r_str [-+]?[0-9]*\.[0-9]+([eE][-+]?[0-9]+)?[Ff]){" instead.
#
# WARNING: deprecated syntax "(macrocall @r_str [-+]?[0-9]*[0-9]+([eE][-+]?[0-9]+)?[Ff]) {".
# Use "(macrocall @r_str [-+]?[0-9]*[0-9]+([eE][-+]?[0-9]+)?[Ff]){" instead.
#
# WARNING: deprecated syntax "(macrocall @r_str [-+]?[0-9]*\.?[0-9]+([eE][-+]?[0-9]+)?[dD]) {".
# Use "(macrocall @r_str [-+]?[0-9]*\.?[0-9]+([eE][-+]?[0-9]+)?[dD]){" instead.
#
# WARNING: deprecated syntax "|(float_with_dot_matcher,float_no_dot_matcher) {".
# Use "|(float_with_dot_matcher,float_no_dot_matcher){" instead.
#
# WARNING: deprecated syntax "(macrocall @r_str [-+]?\d+) {".
# Use "(macrocall @r_str [-+]?\d+){" instead.
#
# ...

# %% [markdown]
# # Getting evaluation

# %%
temp = """
g() = Array(Int)

f() = begin
       x= g()
       x[1] =1
       x
       end
"""
# Out:
# "g() = Array(Int)\n\nf() = begin\n       x= g()\n       x[1] =1\n       x\n       end\n"

# %%
@>> C.parse_file(temp) eval map(x->code_typed(x, optimize=false))
# Out:
# 2-element Array{Any,1}:
#  Any[]
#  Any[]

# %%
@as _ """
function f()
    x = 1
    g() = 2
    z(y) = y + 3
    t() = Array(Int)
    t = t()
    t[1] = x + g() + z(y)
end
""" C.parse_file(_) eval(_[1]) code_typed(_, optimize=false)#map(x->code_typed(x, optimize=false), _.args[2].args)
# Out:
# f (generic function with 1 method)

# %%
@as _ """
import C
    x = 1
    g() = 2
    z(y) = y + 3
    t() = Array(Int)
    m = t()
    m[1] = x + g() + z(x)
""" begin
    string("x-> begin\n", _, "end") 
    C.parse_file(_) 
    eval(_[1]) 
    code_typed(_, optimize=false)
#     x->x[1].args[3].args 
#     C.parse_ast(_, C.Selector(Any[x->isa(x, SymbolNode), x->ndims(x.typ) == 0])) 
    #map(x->code_typed(eval(x), optimize=false), _.args[2].args)
end
# Out:
# 1-element Array{Any,1}:
#  :($(Expr(:lambda, Any[symbol("#self#"),:x], Any[Any[Any[symbol("#self#"),##63#64,0],Any[:x,Any,18],Any[:g,#g#65,66],Any[:z,#z#66,66],Any[:t,#t#67,66],Any[:m,Array{Int64,0},18]],Any[],Any[Int64]], :(begin  # none, line 1: # none, line 2:
#         import C # none, line 3:
#         x = 1 # none, line 4:
#         g = $(Expr(:new, :(Main.#g#65)))
#         g::#g#65 # none, line 5:
#         z = $(Expr(:new, :(Main.#z#66)))
#         z::#z#66 # none, line 6:
#         t = $(Expr(:new, :(Main.#t#67)))
#         t::#t#67 # none, line 7:
#         m = (t::#t#67)()::Array{Int64,0} # none, line 8:
#         GenSym(0) = (x::Int64 + (g::#g#65)()::Int64 + (z::#z#66)(x::Int64)::Int64)::Int64
#         (Main.setindex!)(m::Array{Int64,0},GenSym(0),1)::Array{Int64,0}
#         return GenSym(0)
#     end::Int64))))

# %%
content = """
x = 1
g() = 2
z(y) = y + 3
t() = Array(Int)
m = t()
m[1] = x + g() + z(x)
m
"""
# Out:
# "x = 1\ng() = 2\nz(y) = y + 3\nt() = Array(Int)\nm = t()\nm[1] = x + g() + z(x)\nm\n"

# %%
out_s = let _ = content
    _ = string("u -> begin\n", _, "end")
    _ = C.parse_file(_)[1]
    _ = eval(_)
    _ = code_typed(_, optimize=false)
#     _[1].args[2][1]
end
# Out:
# 1-element Array{Any,1}:
#  :($(Expr(:lambda, Any[symbol("#self#"),:u], Any[Any[Any[symbol("#self#"),##270#271,0],Any[:u,Any,0],Any[:x,Int64,18],Any[:g,#g#272,66],Any[:z,#z#273,66],Any[:t,#t#274,66],Any[:m,Array{Int64,0},18]],Any[],Any[Int64]], :(begin  # none, line 1: # none, line 3:
#         x = 1 # none, line 4:
#         g = $(Expr(:new, :(Main.#g#272)))
#         g::#g#272 # none, line 5:
#         z = $(Expr(:new, :(Main.#z#273)))
#         z::#z#273 # none, line 6:
#         t = $(Expr(:new, :(Main.#t#274)))
#         t::#t#274 # none, line 7:
#         m = (t::#t#274)()::Array{Int64,0} # none, line 8:
#         GenSym(0) = (x::Int64 + (g::#g#272)()::Int64 + (z::#z#273)(x::Int64)::Int64)::Int64
#         (Main.setindex!)(m::Array{Int64,0},GenSym(0),1)::Array{Int64,0} # none, line 9:
#         return m::Array{Int64,0}
#     end::Array{Int64,0}))))

# %%
content_module = """
module T
import C
import Compose
export x, y

module Tx
x = 2
end
import Tx
x = 1
hgs = Compose.context() # If not in main, will not do complete inference
g() = 2
z(y) = y + Tx.x
t() = Array(Int)
c = C.search_dirs("/Users/isaac/GoogleDrive/Work/Julia/JuliaUsage")
m = t()
m[1] = x + g() + z(x)
m
end
"""

parse(content_module);

# %%
bare_module = """
using Base
"""

# %%
out_q = let _ = C.parse_file(content) #content
    _ = Expr(:block, _...) # Modules should presumably already have this
    _ = quote u->$_; end
#     _ = eval(_)
#     _ = code_typed(_, optimize=false) 
end

# %% [markdown]
# # Dynamic analysis stuff
#
# * There can be interior modules, but they get parsed way differently, I should just rely on

# %%
# let _ = C.parse_file(content_module) #content
#     _ = _[1]args[3].args[3:end] # has extra stuff I don't need, eval methods
# let _ = parse(content_module)
let _ = parse(open("temp.jl"))
#     _.head
    _.head
#     m = eval(_)
#     _ = _.args[3].args[3:end]
#     map()
#     _ = Expr(:block, _...)
#     _ = Expr(:block, _...) # Modules should presumably already have this
#     _ = quote u->$_; end
#     _ = eval(_)
#     _ = code_typed(_, optimize=false) 
#     _[1].args[3]
end
# Out:
# :module

# %%
"""Returns type inferred ast for a script"""
function parse_script(file_path::AbstractString)
    let _ = C.parse_file(content) #content
        _ = Expr(:block, _...) # Modules should presumably already have this
        _ = quote u->$_; end
        _ = eval(_)
        _ = code_typed(_, optimize=false) 
        _[1].args[3] # Gives just the expression I want
    end
end
# Out:
# WARNING: Method definition parse_script(AbstractString) in module Main at In[130]:3 overwritten at In[132]:3.
# WARNING: replacing docs for 'parse_script :: Tuple{AbstractString}'.
# parse_script

# %%
# works?
parse_script(content)
# Out:
# :(begin  # In[132], line 5:
#         x = 1
#         g = $(Expr(:new, :(Main.#g#144)))
#         g::#g#144
#         z = $(Expr(:new, :(Main.#z#145)))
#         z::#z#145
#         t = $(Expr(:new, :(Main.#t#146)))
#         t::#t#146
#         m = (t::#t#146)()::Array{Int64,0}
#         GenSym(0) = (x::Int64 + (g::#g#144)()::Int64 + (z::#z#145)(x::Int64)::Int64)::Int64
#         (Main.setindex!)(m::Array{Int64,0},GenSym(0),1)::Array{Int64,0}
#         return m::Array{Int64,0}
#     end::Array{Int64,0})

# %%
"""Returns type inferred ast for contents of a module (- module definition)"""
function parse_module(file_path::AbstractString)
#     let _ = C.parse_file(file_path) #content
#         _ = _[1].args[3].args[3:end] # This is the difference for modules and scripts
    let _ = parse(file_path)
        _ = _.args[3].args[3:end]
        # Filter for modules
        # Call this on them, I guess?
        module_idx = map(x->isdefined(x, :head) ? x.head != :module : true, _)
        filtered = []
#         for (idx, b) in enumerate(module_idx)
#             if b
#                 push!(filtered)
#             else
#                 eval()
            
#         _ = filter(x->isdefined(x, :head) ? x.head != :module : true, _)
        _ = Expr(:block, _...)
        _ = quote u->$_; end
        _ = eval(_)
        _ = code_typed(_, optimize=false) 
        _[1].args[3]
    end
end
# Out:
# WARNING: Method definition parse_module(AbstractString) in module Main at In[94]:5 overwritten at In[96]:5.
# WARNING: replacing docs for 'parse_module :: Tuple{AbstractString}'.
# parse_module

# %%
function parse_module(file_path::AbstractString)
    let _ = C.parse_file(file_path) #content
#         _ = _[1].args[3].args[3:end]
        for i in _
            if C.field(i, :head) == :module
                eval_module(i)

# %%
"""Dealing with modules within modules"""
function eval_module(ast::Expr)
    let _ = Expr.args[3].args[3:end]
        module_idx = map(x->isdefined(x, :head) ? x.head != :module : true, _)
        filtered = []
        for (idx, b) in enumerate(module_idx)
            if b
                push!(filtered, _[idx])
            else
                eval_module(_[idx]) # Do I push this to other modules to 
            end
        end
        _ = filtered
        _ = Expr(:block, _...)
        _ = quote u->$_; end
        _ = eval(_)
        _ = code_typed(_, optimize=false) 
        _[1].args[3]
    end
end
# Out:
# WARNING: Method definition eval_module(Expr) in module Main at In[41]:3 overwritten at In[84]:3.
# WARNING: replacing docs for 'eval_module :: Tuple{Expr}'.
# eval_module

# %%
# tests
parse_module(content_module)
# eval_module(content_module)
# parse_module("temp.jl")
# Out:
# :(begin  # In[96], line 17: # none, line 2:
#         import C # none, line 3:
#         import Compose # none, line 4:
#         export x::Union{}, y # none, line 6: # none, line 9:
#         import Tx # none, line 10:
#         x = 1 # none, line 11:
#         hgs = ((top(getfield))(Main.Compose,:context))() # none, line 12:
#         g = $(Expr(:new, :(Main.#g#68)))
#         g::#g#68 # none, line 13:
#         z = $(Expr(:new, :(Main.#z#69)))
#         z::#z#69 # none, line 14:
#         t = $(Expr(:new, :(Main.#t#70)))
#         t::#t#70 # none, line 15:
#         c = (C.search_dirs)("/Users/isaac/GoogleDrive/Work/Julia/JuliaUsage")::Array{AbstractString,1} # none, line 16:
#         m = (t::#t#70)()::Array{Int64,0} # none, line 17:
#         GenSym(0) = x::Int64 + (g::#g#68)()::Int64 + (z::#z#69)(x::Int64)
#         (Main.setindex!)(m::Array{Int64,0},GenSym(0),1)::Array{Int64,0} # none, line 18:
#         return m::Array{Int64,0}
#     end::Array{Int64,0})

# %% [markdown]
# How to determine if a file is a module or a script
#
# * Break a file into top-level expressions
# * If expression is a module, eval it as module
#     * Search inside for modules to also eval as modules
# * Group all other expressions together
#
# # Uh oh
#
# * macros are just inherently unsafe, you have to run all capabilities of julia to compile julia
#     * Can I check julia code for accessing filesystem?
#     * I guess runnin
# * I think wrapping scripts in lambdas
#
# If I want to compile code, I have to expand macros. Expanding macros allows for arbitrary code execution. Probably running it with super limited permissions on a docker would work, but I can't be sure that won't break functionallity. But there's already probably gonna be a fair bit of broken functionality.
#
# ## Things to do before this is that relevant
#
# * Figure out flow for evaluating contents of modules
#     * Scope
#         * How do I scope evaluation?
#             * Do all of it in a module?
#         * How do I deal with evaluating so many modules?
#             * Do I clear memory?
#                 * Pretty sure `workspace()` doesn't actually do this
#                     * Everything previously evaluated is available through nested LastMain
#             * Do I have to start a new process?
#                 * How much speed does this lose me? I just worked pretty hard on having that.
#             * Embrace the DAG?
#                 * Could possibly figure out most efficient import paths
#     * Distribution to processors
#         * Probably makes sense to have a process evaluate an entire module then, to keep content loading to a minimum
